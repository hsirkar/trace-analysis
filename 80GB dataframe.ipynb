# %%
# https://modin.readthedocs.io/en/latest/getting_started/why_modin/out_of_core.html

# %%
import pandas
import numpy as np

# %%
# 80GB DF
df = pandas.concat([pandas.DataFrame(np.random.randint(0, 100, size=(2**20, 2**8))) for _ in range(40)]) # Memory Error!

# %%
import modin.pandas as pd
import numpy as np
df = pd.concat([pd.DataFrame(np.random.randint(0, 100, size=(2**20, 2**8))) for _ in range(40)]) # 40x2GB frames -- Working!
df.info()
# Out:
# UserWarning: Distributing <class 'numpy.ndarray'> object. This may take some time.
# UserWarning: Distributing <class 'numpy.ndarray'> object. This may take some time.
# UserWarning: Distributing <class 'numpy.ndarray'> object. This may take some time.
# (raylet) Spilled 6720 MiB, 211 objects, write throughput 81 MiB/s.
# UserWarning: Distributing <class 'numpy.ndarray'> object. This may take some time.
# (raylet) Spilled 8256 MiB, 259 objects, write throughput 79 MiB/s.
# UserWarning: Distributing <class 'numpy.ndarray'> object. This may take some time.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import modin.pandas as pd
#       2 import numpy as np
# ----> 3 df = pd.concat([pd.DataFrame(np.random.randint(0, 100, size=(2**20, 2**8))) for _ in range(40)]) # 40x2GB frames -- Working!
#       4 df.info()
#
# Cell In[3], line 3, in <listcomp>(.0)
#       1 import modin.pandas as pd
#       2 import numpy as np
# ----> 3 df = pd.concat([pd.DataFrame(np.random.randint(0, 100, size=(2**20, 2**8))) for _ in range(40)]) # 40x2GB frames -- Working!
#       4 df.info()
#
# File ~/.local/lib/python3.8/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.local/lib/python3.8/site-packages/modin/pandas/dataframe.py:236, in DataFrame.__init__(self, data, index, columns, dtype, copy, query_compiler)
#     229         data = {
#     230             k: v._to_pandas() if isinstance(v, Series) else v
#     231             for k, v in data.items()
#     232         }
#     233     pandas_df = pandas.DataFrame(
#     234         data=data, index=index, columns=columns, dtype=dtype, copy=copy
#     235     )
# --> 236     self._query_compiler = from_pandas(pandas_df)._query_compiler
#     237 else:
#     238     self._query_compiler = query_compiler
#
# File ~/.local/lib/python3.8/site-packages/modin/pandas/utils.py:96, in from_pandas(df)
#      93 from modin.core.execution.dispatching.factories.dispatcher import FactoryDispatcher
#      94 from .dataframe import DataFrame
# ---> 96 return DataFrame(query_compiler=FactoryDispatcher.from_pandas(df))
#
# File ~/.local/lib/python3.8/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:175, in FactoryDispatcher.from_pandas(cls, df)
#     172 @classmethod
#     173 @_inherit_docstrings(factories.BaseFactory._from_pandas)
#     174 def from_pandas(cls, df):
# --> 175     return cls.get_factory()._from_pandas(df)
#
# File ~/.local/lib/python3.8/site-packages/modin/core/execution/dispatching/factories/factories.py:173, in BaseFactory._from_pandas(cls, df)
#     165 @classmethod
#     166 @doc(
#     167     _doc_io_method_template,
#    (...)
#     171 )
#     172 def _from_pandas(cls, df):
# --> 173     return cls.io_cls.from_pandas(df)
#
# File ~/.local/lib/python3.8/site-packages/modin/core/io/io.py:83, in BaseIO.from_pandas(cls, df)
#      68 @classmethod
#      69 def from_pandas(cls, df):
#      70     """
#      71     Create a Modin `query_compiler` from a `pandas.DataFrame`.
#      72
#    (...)
#      81         QueryCompiler containing data from the `pandas.DataFrame`.
#      82     """
# ---> 83     return cls.query_compiler_cls.from_pandas(df, cls.frame_cls)
#
# File ~/.local/lib/python3.8/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.local/lib/python3.8/site-packages/modin/core/storage_formats/pandas/query_compiler.py:284, in PandasQueryCompiler.from_pandas(cls, df, data_cls)
#     282 @classmethod
#     283 def from_pandas(cls, df, data_cls):
# --> 284     return cls(data_cls.from_pandas(df))
#
# File ~/.local/lib/python3.8/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.local/lib/python3.8/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:3642, in PandasDataframe.from_pandas(cls, df)
#    3640 new_columns = df.columns
#    3641 new_dtypes = df.dtypes
# -> 3642 new_frame, new_lengths, new_widths = cls._partition_mgr_cls.from_pandas(
#    3643     df, True
#    3644 )
#    3645 return cls(
#    3646     new_frame,
#    3647     new_index,
#    (...)
#    3651     dtypes=new_dtypes,
#    3652 )
#
# File ~/.local/lib/python3.8/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.local/lib/python3.8/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:58, in wait_computations_if_benchmark_mode.<locals>.wait(cls, *args, **kwargs)
#      55 @wraps(func)
#      56 def wait(cls, *args, **kwargs):
#      57     """Wait for computation results."""
# ---> 58     result = func(cls, *args, **kwargs)
#      59     if BenchmarkMode.get():
#      60         if isinstance(result, tuple):
#
# File ~/.local/lib/python3.8/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:802, in PandasDataframePartitionManager.from_pandas(cls, df, return_dims)
#     800 else:
#     801     pbar = None
# --> 802 parts = [
#     803     [
#     804         update_bar(
#     805             pbar,
#     806             put_func(df.iloc[i : i + row_chunksize, j : j + col_chunksize]),
#     807         )
#     808         for j in range(0, len(df.columns), col_chunksize)
#     809     ]
#     810     for i in range(0, len(df), row_chunksize)
#     811 ]
#     812 if ProgressBar.get():
#     813     pbar.close()
#
# File ~/.local/lib/python3.8/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:803, in <listcomp>(.0)
#     800 else:
#     801     pbar = None
#     802 parts = [
# --> 803     [
#     804         update_bar(
#     805             pbar,
#     806             put_func(df.iloc[i : i + row_chunksize, j : j + col_chunksize]),
#     807         )
#     808         for j in range(0, len(df.columns), col_chunksize)
#     809     ]
#     810     for i in range(0, len(df), row_chunksize)
#     811 ]
#     812 if ProgressBar.get():
#     813     pbar.close()
#
# File ~/.local/lib/python3.8/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:806, in <listcomp>(.0)
#     800 else:
#     801     pbar = None
#     802 parts = [
#     803     [
#     804         update_bar(
#     805             pbar,
# --> 806             put_func(df.iloc[i : i + row_chunksize, j : j + col_chunksize]),
#     807         )
#     808         for j in range(0, len(df.columns), col_chunksize)
#     809     ]
#     810     for i in range(0, len(df), row_chunksize)
#     811 ]
#     812 if ProgressBar.get():
#     813     pbar.close()
#
# File ~/.local/lib/python3.8/site-packages/modin/core/execution/ray/implementations/pandas_on_ray/partitioning/partition.py:234, in PandasOnRayDataframePartition.put(cls, obj)
#     219 @classmethod
#     220 def put(cls, obj):
#     221     """
#     222     Put an object into Plasma store and wrap it with partition object.
#     223
#    (...)
#     232         A new ``PandasOnRayDataframePartition`` object.
#     233     """
# --> 234     return cls(cls.execution_wrapper.put(obj), len(obj.index), len(obj.columns))
#
# File ~/.local/lib/python3.8/site-packages/modin/core/execution/ray/common/engine_wrapper.py:111, in RayWrapper.put(cls, data, **kwargs)
#      94 @classmethod
#      95 def put(cls, data, **kwargs):
#      96     """
#      97     Store an object in the object store.
#      98
#    (...)
#     109         Ray object identifier to get the value by.
#     110     """
# --> 111     return ray.put(data, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/ray/_private/worker.py:2620, in put(value, _owner)
#    2618 with profiling.profile("ray.put"):
#    2619     try:
# -> 2620         object_ref = worker.put_object(value, owner_address=serialize_owner_address)
#    2621     except ObjectStoreFullError:
#    2622         logger.info(
#    2623             "Put failed since the value was either too large or the "
#    2624             "store was full of pinned objects."
#    2625         )
#
# File ~/.local/lib/python3.8/site-packages/ray/_private/worker.py:707, in Worker.put_object(self, value, object_ref, owner_address)
#     699     raise TypeError(msg) from e
#     700 # This *must* be the first place that we construct this python
#     701 # ObjectRef because an entry with 0 local references is created when
#     702 # the object is Put() in the core worker, expecting that this python
#     703 # reference will be created. If another reference is created and
#     704 # removed before this one, it will corrupt the state in the
#     705 # reference counter.
#     706 return ray.ObjectRef(
# --> 707     self.core_worker.put_serialized_object_and_increment_local_ref(
#     708         serialized_value, object_ref=object_ref, owner_address=owner_address
#     709     ),
#     710     # The initial local reference is already acquired internally.
#     711     skip_adding_local_ref=True,
#     712 )
#
# File python/ray/_raylet.pyx:3266, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref()
#
# KeyboardInterrupt:
